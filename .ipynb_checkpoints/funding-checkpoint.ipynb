# %%
from pybit.unified_trading import HTTP
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import datetime
# Replace 'YOUR_API_KEY' and 'YOUR_API_SECRET' with your own Bybit API credentials
api_key = 'jWhI7F48vMhqFftfE3'
api_secret = 'kMfn8kKoprWnpnRkX1K0bpOMoMJkOzHBcgbC'

# Instantiate the Bybit API client
client = HTTP(testnet=False)

# %%
# Request funding rates
response = client.LinearV2.Market.SymbolInfo()

# Extract the funding rates from the response
funding_rates = response['result']

# Print the funding rates
for pair in funding_rates:
    print(f"Pair: {pair['symbol']}")
    print(f"Funding Rate: {pair['funding_rate']}")
    print("-----")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Request funding rates
# ----> 2 response = client.LinearV2.Market.SymbolInfo()
#       4 # Extract the funding rates from the response
#       5 funding_rates = response['result']
#
# AttributeError: 'HTTP' object has no attribute 'LinearV2'

# %%
def plot_funding_rate(pair):
    # Request funding rate history for the given pair
    response = client.get_funding_rate_history(symbol=pair, category='linear', limit=30)
    # Extract the funding rates and timestamps from the response
    funding_rates = [float(entry['fundingRate'])*100 for entry in response['result']['list']]
    timestamps = [entry['fundingRateTimestamp'] for entry in response['result']['list']]
    dates = [datetime.datetime.fromtimestamp(int(ts) / 1000) for ts in timestamps]


    # Plot the funding rates with dots
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.plot(dates, funding_rates, marker='o', linestyle='-', markersize=5)

    # Format x-axis with date ticks
    ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

    # Add value annotations under each dot
    for i in range(len(dates)):
        ax.text(dates[i], funding_rates[i], str(funding_rates[i])[0:7], ha='center', va='top')

    # Set labels and title
    plt.xlabel('Date')
    plt.ylabel('Funding Rate')
    plt.title(f'Funding Rate History for {pair}')

    # Rotate x-axis tick labels for better readability
    plt.xticks(rotation=45)

    # Show grid
    plt.grid(True)

    # Display the plot
    plt.show()

# %%
pair_to_plot = 'ZRXUSDT'
plot_funding_rate(pair_to_plot)

# %%
reponse = client.get_tickers(
    category="linear"
)

# %%
df = pd.DataFrame(reponse['result']['list'], columns=['symbol', 'fundingRate'])

# %%
pd.set_option('display.max_rows', None)

# %%
df_cleaned = df.dropna(subset=['fundingRate']).drop(df[df['fundingRate'] == ''].index)

# %%
df_cleaned['fundingRate'] = df_cleaned['fundingRate'].apply(lambda x: float(x) * 100)

# %%
df_cleaned.sort_values('fundingRate').reset_index().drop('index', axis=1)
# Out:
#              symbol  fundingRate
# 0           XVGUSDT      -0.8225
# 1       1000XECUSDT      -0.3609
# 2       1000BTTUSDT      -0.1118
# 3           ZRXUSDT      -0.0970
# 4           AXSUSDT      -0.0923
# 5           BNBUSDT      -0.0785
# 6           CVCUSDT      -0.0687
# 7          ALGOUSDT      -0.0635
# 8           FXSUSDT      -0.0566
# 9          COTIUSDT      -0.0524
# 10        SWEATUSDT      -0.0516
# 11         ATOMUSDT      -0.0514
# 12          BELUSDT      -0.0420
# 13          FLRUSDT      -0.0351
# 14          BCHUSDT      -0.0329
# 15          BNBPERP      -0.0316
# 16          GPTUSDT      -0.0233
# 17         COMPUSDT      -0.0226
# 18          GMTUSDT      -0.0201
# 19         BUSDUSDT      -0.0177
# 20         NEARUSDT      -0.0167
# 21          INJUSDT      -0.0163
# 22        WAVESUSDT      -0.0156
# 23     SHIB1000USDT      -0.0152
# 24          APTUSDT      -0.0149
# 25          STGUSDT      -0.0144
# 26         ARPAUSDT      -0.0143
# 27          LPTUSDT      -0.0135
# 28         KAVAUSDT      -0.0104
# 29        STORJUSDT      -0.0098
# 30          CHZUSDT      -0.0090
# 31         GALAUSDT      -0.0086
# 32     1000PEPEUSDT      -0.0085
# 33         HIGHUSDT      -0.0078
# 34          XMRUSDT      -0.0077
# 35         AGIXUSDT      -0.0074
# 36          CTKUSDT      -0.0069
# 37          ICXUSDT      -0.0061
# 38          FTMUSDT      -0.0052
# 39        JASMYUSDT      -0.0052
# 40          FILUSDT      -0.0049
# 41          XLMUSDT      -0.0049
# 42          KDAUSDT      -0.0048
# 43          SNXUSDT      -0.0046
# 44          BSVUSDT      -0.0041
# 45          CKBUSDT      -0.0039
# 46          EDUUSDT      -0.0039
# 47          NEOUSDT      -0.0039
# 48         ANKRUSDT      -0.0031
# 49          SUNUSDT      -0.0027
# 50          ENSUSDT      -0.0024
# 51          ONEUSDT      -0.0024
# 52          TRXUSDT      -0.0023
# 53         QTUMUSDT      -0.0022
# 54          ADAUSDT      -0.0013
# 55          LRCUSDT      -0.0012
# 56         RDNTUSDT      -0.0009
# 57        MAGICUSDT      -0.0009
# 58         USDCUSDT       0.0000
# 59         BOBAUSDT       0.0000
# 60     10000NFTUSDT       0.0008
# 61          SUIUSDT       0.0012
# 62         LINAUSDT       0.0018
# 63          BNXUSDT       0.0021
# 64           ARUSDT       0.0024
# 65          CTCUSDT       0.0026
# 66          ANTUSDT       0.0028
# 67         AVAXUSDT       0.0031
# 68          ETCPERP       0.0031
# 69          GMXUSDT       0.0034
# 70         ASTRUSDT       0.0034
# 71          ONTUSDT       0.0036
# 72          FETUSDT       0.0037
# 73         SCRTUSDT       0.0038
# 74          IMXUSDT       0.0040
# 75          UNIUSDT       0.0045
# 76         CTSIUSDT       0.0047
# 77         DOGEUSDT       0.0049
# 78         RNDRUSDT       0.0050
# 79          NKNUSDT       0.0054
# 80         MASKUSDT       0.0054
# 81         BANDUSDT       0.0059
# 82          SOLUSDT       0.0061
# 83         MANAUSDT       0.0064
# 84          GFTUSDT       0.0065
# 85          ETHUSDT       0.0069
# 86          KNCUSDT       0.0075
# 87         LINKUSDT       0.0079
# 88          TRUUSDT       0.0085
# 89          OMGUSDT       0.0097
# 90          CRVUSDT       0.0099
# 91          XCNUSDT       0.0100
# 92           OPPERP       0.0100
# 93          SKLUSDT       0.0100
# 94          XEMUSDT       0.0100
# 95           OPUSDT       0.0100
# 96         ORDIUSDT       0.0100
# 97         UNFIUSDT       0.0100
# 98         PAXGUSDT       0.0100
# 99       PENDLEUSDT       0.0100
# 100         WOOUSDT       0.0100
# 101         VETUSDT       0.0100
# 102         XNOUSDT       0.0100
# 103      PEOPLEUSDT       0.0100
# 104       OCEANUSDT       0.0100
# 105         XRPPERP       0.0100
# 106         XRPUSDT       0.0100
# 107         XTZUSDT       0.0100
# 108         YFIUSDT       0.0100
# 109         YGGUSDT       0.0100
# 110         MTLUSDT       0.0100
# 111         ZECUSDT       0.0100
# 112         ZENUSDT       0.0100
# 113         MKRUSDT       0.0100
# 114         OGNUSDT       0.0100
# 115         UMAUSDT       0.0100
# 116         QNTUSDT       0.0100
# 117         PHBUSDT       0.0100
# 118          SCUSDT       0.0100
# 119         SLPUSDT       0.0100
# 120        SANDUSDT       0.0100
# 121         SOLPERP       0.0100
# 122        MINAUSDT       0.0100
# 123         RVNUSDT       0.0100
# 124        RUNEUSDT       0.0100
# 125        RSS3USDT       0.0100
# 126       SPELLUSDT       0.0100
# 127         SSVUSDT       0.0100
# 128        STMXUSDT       0.0100
# 129         RSRUSDT       0.0100
# 130         RPLUSDT       0.0100
# 131         STXUSDT       0.0100
# 132       SUSHIUSDT       0.0100
# 133       THETAUSDT       0.0100
# 134        ROSEUSDT       0.0100
# 135         TLMUSDT       0.0100
# 136         RLCUSDT       0.0100
# 137         REQUSDT       0.0100
# 138        TOMOUSDT       0.0100
# 139         RENUSDT       0.0100
# 140        REEFUSDT       0.0100
# 141         TRBUSDT       0.0100
# 142         RADUSDT       0.0100
# 143           TUSDT       0.0100
# 144         SFPUSDT       0.0100
# 145         TWTUSDT       0.0100
# 146         MDTUSDT       0.0100
# 147  10000LADYSUSDT       0.0100
# 148       MATICUSDT       0.0100
# 149         BSWUSDT       0.0100
# 150         BTCPERP       0.0100
# 151         BTCUSDT       0.0100
# 152         C98USDT       0.0100
# 153        CEEKUSDT       0.0100
# 154        CELOUSDT       0.0100
# 155        CELRUSDT       0.0100
# 156         CFXUSDT       0.0100
# 157         CHRUSDT       0.0100
# 158       COMBOUSDT       0.0100
# 159        COREUSDT       0.0100
# 160         CROUSDT       0.0100
# 161         CVXUSDT       0.0100
# 162         DARUSDT       0.0100
# 163        DASHUSDT       0.0100
# 164        DENTUSDT       0.0100
# 165         DGBUSDT       0.0100
# 166         BLZUSDT       0.0100
# 167        DODOUSDT       0.0100
# 168        BLURUSDT       0.0100
# 169         BATUSDT       0.0100
# 170    1000BONKUSDT       0.0100
# 171   1000FLOKIUSDT       0.0100
# 172    1000LUNCUSDT       0.0100
# 173       1INCHUSDT       0.0100
# 174        AAVEUSDT       0.0100
# 175         ACHUSDT       0.0100
# 176        AGLDUSDT       0.0100
# 177        AKROUSDT       0.0100
# 178       ALICEUSDT       0.0100
# 179       ALPHAUSDT       0.0100
# 180         AMBUSDT       0.0100
# 181         APEUSDT       0.0100
# 182        API3USDT       0.0100
# 183         ARBUSDT       0.0100
# 184       AUDIOUSDT       0.0100
# 185        BAKEUSDT       0.0100
# 186         BALUSDT       0.0100
# 187        BICOUSDT       0.0100
# 188         MAVUSDT       0.0100
# 189         DOTUSDT       0.0100
# 190        DYDXUSDT       0.0100
# 191         ZILUSDT       0.0100
# 192        IOSTUSDT       0.0100
# 193        IOTAUSDT       0.0100
# 194        IOTXUSDT       0.0100
# 195         JOEUSDT       0.0100
# 196         JSTUSDT       0.0100
# 197         KEYUSDT       0.0100
# 198        KLAYUSDT       0.0100
# 199         KSMUSDT       0.0100
# 200         LDOUSDT       0.0100
# 201       LEVERUSDT       0.0100
# 202         LITUSDT       0.0100
# 203       LOOKSUSDT       0.0100
# 204        LQTYUSDT       0.0100
# 205         LTCUSDT       0.0100
# 206       LUNA2USDT       0.0100
# 207       MATICPERP       0.0100
# 208          IDUSDT       0.0100
# 209        IDEXUSDT       0.0100
# 210         ICPUSDT       0.0100
# 211         HOTUSDT       0.0100
# 212        EGLDUSDT       0.0100
# 213         ENJUSDT       0.0100
# 214         EOSUSDT       0.0100
# 215         ETCUSDT       0.0100
# 216         ETHPERP       0.0100
# 217        ETHWUSDT       0.0100
# 218       FITFIUSDT       0.0100
# 219         FLMUSDT       0.0100
# 220        DUSKUSDT       0.0100
# 221        FLOWUSDT       0.0100
# 222        GLMRUSDT       0.0100
# 223         GRTUSDT       0.0100
# 224         GTCUSDT       0.0100
# 225        HBARUSDT       0.0100
# 226         HFTUSDT       0.0100
# 227         HNTUSDT       0.0100
# 228        HOOKUSDT       0.0100
# 229         GALUSDT       0.0100
# 230         ILVUSDT       0.0100
# 231         SXPUSDT       0.0230

# %%
response = client.get_funding_rate_history(symbol='ETHPERP', category='linear')

# %%
response
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'linear',
#   'list': [{'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688659200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688630400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688601600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688572800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688544000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688515200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688486400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688457600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688428800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688400000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688371200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688342400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688313600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688284800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688256000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688227200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688198400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688169600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688140800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688112000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688083200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688054400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1688025600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687996800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687968000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687939200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.000061',
#     'fundingRateTimestamp': '1687910400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687881600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687852800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687824000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687795200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687766400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687737600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00004707',
#     'fundingRateTimestamp': '1687708800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00008147',
#     'fundingRateTimestamp': '1687680000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687651200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687622400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687593600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687564800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687536000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687507200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687478400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0000709',
#     'fundingRateTimestamp': '1687449600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687420800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00014398',
#     'fundingRateTimestamp': '1687392000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00024038',
#     'fundingRateTimestamp': '1687363200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00036972',
#     'fundingRateTimestamp': '1687334400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00047565',
#     'fundingRateTimestamp': '1687305600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00000281',
#     'fundingRateTimestamp': '1687276800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00001162',
#     'fundingRateTimestamp': '1687248000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00003119',
#     'fundingRateTimestamp': '1687219200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00003786',
#     'fundingRateTimestamp': '1687190400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687161600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687132800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687104000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687075200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687046400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1687017600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00008524',
#     'fundingRateTimestamp': '1686988800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00006493',
#     'fundingRateTimestamp': '1686960000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00023477',
#     'fundingRateTimestamp': '1686931200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686902400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686873600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686844800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686816000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686787200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686758400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686729600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686700800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686672000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686643200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686614400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686585600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686556800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686528000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686499200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686470400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686441600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686412800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686384000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686355200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686326400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686297600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686268800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686240000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686211200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686182400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686153600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00006986',
#     'fundingRateTimestamp': '1686124800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00007696',
#     'fundingRateTimestamp': '1686096000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686067200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686038400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1686009600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685980800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685952000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685923200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685894400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685865600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685836800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685808000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685779200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685750400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685721600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685692800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685664000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685635200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685606400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685577600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685548800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685520000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685491200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00004558',
#     'fundingRateTimestamp': '1685462400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685433600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685404800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685376000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685347200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00009696',
#     'fundingRateTimestamp': '1685318400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00002972',
#     'fundingRateTimestamp': '1685289600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00000365',
#     'fundingRateTimestamp': '1685260800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00000328',
#     'fundingRateTimestamp': '1685232000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00006953',
#     'fundingRateTimestamp': '1685203200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.0000536',
#     'fundingRateTimestamp': '1685174400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00008739',
#     'fundingRateTimestamp': '1685145600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00008515',
#     'fundingRateTimestamp': '1685116800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685088000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685059200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685030400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1685001600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684972800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684944000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684915200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00007368',
#     'fundingRateTimestamp': '1684886400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00007343',
#     'fundingRateTimestamp': '1684857600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00005779',
#     'fundingRateTimestamp': '1684828800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684800000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684771200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684742400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684713600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684684800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00008421',
#     'fundingRateTimestamp': '1684656000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684627200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684598400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684569600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684540800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684512000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684483200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684454400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684425600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684396800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684368000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684339200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684310400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684281600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684252800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684224000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684195200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00000519',
#     'fundingRateTimestamp': '1684166400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684137600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684108800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00006822',
#     'fundingRateTimestamp': '1684080000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684051200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1684022400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683993600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683964800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683936000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683907200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683878400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683849600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683820800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683792000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683763200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683734400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683705600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00007737',
#     'fundingRateTimestamp': '1683676800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683648000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683619200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683590400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683561600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683532800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683504000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '-0.00009355',
#     'fundingRateTimestamp': '1683475200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.00008752',
#     'fundingRateTimestamp': '1683446400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683417600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683388800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683360000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683331200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683302400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683273600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683244800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683216000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683187200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683158400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683129600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683100800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683072000000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683043200000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1683014400000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1682985600000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1682956800000'},
#    {'symbol': 'ETHPERP',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1682928000000'}]},
#  'retExtInfo': {},
#  'time': 1688684940058}
